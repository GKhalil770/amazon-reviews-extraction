# %% [markdown]
# <a href="https://colab.research.google.com/github/GKhalil770/amazon-reviews-extraction/blob/main/Amazon_review_collector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install pandas (only need to run once)
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Import necessary libraries
import pandas as pd
import zipfile
import os

# %%
# Paths
zip_path = '/content/test.csv.zip'    # Path to your uploaded zip file
extract_path = '/content/data/'        # Directory to extract contents

# Create the directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Unzip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Unzipped the file!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-351a9699b584> in <cell line: 0>()
#       7
#       8 # Unzip
# ----> 9 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      10     zip_ref.extractall(extract_path)
#      11
#
# /usr/lib/python3.11/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1293             while True:
#    1294                 try:
# -> 1295                     self.fp = io.open(file, filemode)
#    1296                 except OSError:
#    1297                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test.csv.zip'

# %%
# Find CSV file inside extracted folder
csv_files = [file for file in os.listdir(extract_path) if file.endswith('.csv')]

# Error if not found
if not csv_files:
    raise Exception("❌ No CSV file found in the zip!")

# Full path to the CSV
csv_path = os.path.join(extract_path, csv_files[0])
print(f"✅ Found CSV file: {csv_files[0]}")

# Load the CSV into a Pandas DataFrame
df = pd.read_csv(csv_path)

print("✅ Loaded dataset!")

# %%
# Set display options to show everything clearly
pd.set_option('display.max_columns', None)   # Show all columns
pd.set_option('display.max_rows', 200)        # Show up to 200 rows (change if needed)
pd.set_option('display.max_colwidth', None)   # Show full text in cells

print("✅ Pandas display options set!")

# %%
# Display columns
print("\n🧩 Available columns:")
print(list(df.columns))

# Display first few rows
print("\n📊 First few rows of data:")
display(df.head())

# %%
# Print every review one-by-one
if 'reviewText' in df.columns:
    print("\n📝 All Reviews:\n")
    for idx, review in enumerate(df['reviewText']):
        print(f"--- Review #{idx+1} ---")
        print(review)
        print("\n")
else:
    print("⚠️ No 'reviewText' column found in the dataset.")

# %%
# !git status
